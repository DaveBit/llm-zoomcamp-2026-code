# %%
from rag_helper import RAGBase
# Out:
# Traceback (most recent call last):
#
#   File /workspaces/llm-zoomcamp-2026-code/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3748 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 1
#     from rag_helper import RAGBase
#
#   File /workspaces/llm-zoomcamp-2026-code/rag_helper.py:1
#     def search(self, query, num_results=5):
#     ^
# IndentationError: unexpected indent
