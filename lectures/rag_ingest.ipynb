# %%
from ingest import load_faq_data
from pprint import pprint

# set path to your FAQ file or directory (update as needed)
faq_source = "data/faqs"  # e.g. "data/faq.csv" or a folder

faqs = load_faq_data(faq_source)

# quick check
print(type(faqs))
pprint(faqs if isinstance(faqs, (list, tuple)) else [faqs])
